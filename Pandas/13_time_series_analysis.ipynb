# %% [markdown]
# # Import Required Libraries
# This cell imports the necessary libraries and sets display options for pandas.

# %%
# Import required libraries
import pandas as pd
import numpy as np

# Set display options for better readability
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 100)

# %% [markdown]
# # Creating Time Series Data
# This cell demonstrates how to create time series data using pandas. It includes examples of creating `DatetimeIndex`, `Series`, and `DataFrame` objects with time-based indices.

# %%
# 1. Creating Time Series Data
# -------------------------------------------------
# Create a DatetimeIndex with daily frequency
dates = pd.date_range(start='2023-01-01', periods=10, freq='D')
print(f"DatetimeIndex:\n{dates}\n")

# Create a Series with DatetimeIndex as the index
ts = pd.Series(np.random.randn(10), index=dates)
print(f"Time Series:\n{ts}\n")

# Create a DataFrame with DatetimeIndex as the index
df_ts = pd.DataFrame({
    'A': np.random.randn(10),
    'B': np.random.randn(10) + 1
}, index=dates)
print(f"DataFrame with DatetimeIndex:\n{df_ts}\n")

# Create date ranges with different frequencies
weekly = pd.date_range('2023-01-01', periods=5, freq='W')
monthly = pd.date_range('2023-01-01', periods=5, freq='M')
quarterly = pd.date_range('2023-01-01', periods=4, freq='Q')
yearly = pd.date_range('2023-01-01', periods=3, freq='Y')
business_days = pd.date_range('2023-01-01', periods=5, freq='B')
hourly = pd.date_range('2023-01-01', periods=5, freq='H')

# Print all the ranges to understand their structure
print(f"Weekly:\n{weekly}\n")
print(f"Monthly:\n{monthly}\n")
print(f"Quarterly:\n{quarterly}\n")
print(f"Yearly:\n{yearly}\n")
print(f"Business Days:\n{business_days}\n")
print(f"Hourly:\n{hourly}\n")
# Out:
# DatetimeIndex:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06',
#                '2023-01-07', '2023-01-08', '2023-01-09', '2023-01-10'],
#               dtype='datetime64[ns]', freq='D')
#
# Time Series:
# 2023-01-01   -0.186908
# 2023-01-02    1.130827
# 2023-01-03    0.819090
# 2023-01-04   -0.367737
# 2023-01-05   -1.331599
# 2023-01-06   -0.635508
# 2023-01-07    1.193803
# 2023-01-08   -1.819772
# 2023-01-09    1.509393
# 2023-01-10   -0.455032
# Freq: D, dtype: float64
#
# DataFrame with DatetimeIndex:
#                    A         B
# 2023-01-01 -0.597604  2.312057
# 2023-01-02  1.009314  1.403705
# 2023-01-03  1.397387  0.862337
# 2023-01-04  0.619055  1.286351
# 2023-01-05  1.340652  1.843871
# 2023-01-06  0.870460  2.111612
# 2023-01-07  1.511823  1.445195
# 2023-01-08 -0.433860  0.712905
# 2023-01-09  0.102099  1.137769
# 2023-01-10  0.397355  0.936116
#
# Weekly:
# DatetimeIndex(['2023-01-01', '2023-01-08', '2023-01-15', '2023-01-22', '2023-01-29'], dtype='datetime64[ns]', freq='W-SUN')
#
# Monthly:
# DatetimeIndex(['2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30', '2023-05-31'], dtype='datetime64[ns]', freq='M')
#
# Quarterly:
# DatetimeIndex(['2023-03-31', '2023-06-30', '2023-09-30', '2023-12-31'], dtype='datetime64[ns]', freq='Q-DEC')
#
# Yearly:
# DatetimeIndex(['2023-12-31', '2024-12-31', '2025-12-31'], dtype='datetime64[ns]', freq='A-DEC')
#
# Business Days:
# DatetimeIndex(['2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05', '2023-01-06'], dtype='datetime64[ns]', freq='B')
#
# Hourly:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 01:00:00', '2023-01-01 02:00:00',
#                '2023-01-01 03:00:00', '2023-01-01 04:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %% [markdown]
# # Extracting Date and Time Components
# This cell shows how to extract various date and time components (like year, month, day, etc.) from a `DatetimeIndex`.

# %%
# 2. Date and Time Components
# -------------------------------------------------
# Create a DatetimeIndex with hourly frequency
datetime_idx = pd.date_range('2023-01-01 12:30:45', periods=5, freq='H')
print(f"DatetimeIndex with time components:\n{datetime_idx}\n")

# Extract date components
year = datetime_idx.year
month = datetime_idx.month
day = datetime_idx.day
dayofweek = datetime_idx.dayofweek  # Monday=0, Sunday=6
dayofyear = datetime_idx.dayofyear
quarter = datetime_idx.quarter
print(f"Year: {year}\nMonth: {month}\nDay: {day}\nDay of Week: {dayofweek}\nDay of Year: {dayofyear}\nQuarter: {quarter}\n")

# Extract time components
hour = datetime_idx.hour
minute = datetime_idx.minute
second = datetime_idx.second
print(f"Hour: {hour}\nMinute: {minute}\nSecond: {second}\n")
# Out:
# DatetimeIndex with time components:
# DatetimeIndex(['2023-01-01 12:30:45', '2023-01-01 13:30:45', '2023-01-01 14:30:45',
#                '2023-01-01 15:30:45', '2023-01-01 16:30:45'],
#               dtype='datetime64[ns]', freq='H')
#
# Year: Int64Index([2023, 2023, 2023, 2023, 2023], dtype='int64')
# Month: Int64Index([1, 1, 1, 1, 1], dtype='int64')
# Day: Int64Index([1, 1, 1, 1, 1], dtype='int64')
# Day of Week: Int64Index([6, 6, 6, 6, 6], dtype='int64')
# Day of Year: Int64Index([1, 1, 1, 1, 1], dtype='int64')
# Quarter: Int64Index([1, 1, 1, 1, 1], dtype='int64')
#
# Hour: Int64Index([12, 13, 14, 15, 16], dtype='int64')
# Minute: Int64Index([30, 30, 30, 30, 30], dtype='int64')
# Second: Int64Index([45, 45, 45, 45, 45], dtype='int64')

# %% [markdown]
# # Time Zone Handling
# This cell demonstrates how to handle time zones in pandas, including localizing naive datetime objects and converting between time zones.

# %%
# 3. Time Zone Handling
# -------------------------------------------------
# Create a timezone-naive DatetimeIndex
naive_idx = pd.date_range('2023-01-01', periods=5, freq='D')
print(f"Naive DatetimeIndex:\n{naive_idx}\n")

# Localize to a specific timezone (UTC)
utc_idx = naive_idx.tz_localize('UTC')
print(f"UTC Localized:\n{utc_idx}\n")

# Convert to a different timezone (US/Eastern)
eastern = utc_idx.tz_convert('US/Eastern')
print(f"Converted to US/Eastern:\n{eastern}\n")

# Create timezone-aware DatetimeIndex directly
aware_idx = pd.date_range('2023-01-01', periods=5, freq='D', tz='US/Pacific')
print(f"Timezone-aware DatetimeIndex:\n{aware_idx}\n")
# Out:
# Naive DatetimeIndex:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'], dtype='datetime64[ns]', freq='D')
#
# UTC Localized:
# DatetimeIndex(['2023-01-01 00:00:00+00:00', '2023-01-02 00:00:00+00:00',
#                '2023-01-03 00:00:00+00:00', '2023-01-04 00:00:00+00:00',
#                '2023-01-05 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq='D')
#
# Converted to US/Eastern:
# DatetimeIndex(['2022-12-31 19:00:00-05:00', '2023-01-01 19:00:00-05:00',
#                '2023-01-02 19:00:00-05:00', '2023-01-03 19:00:00-05:00',
#                '2023-01-04 19:00:00-05:00'],
#               dtype='datetime64[ns, US/Eastern]', freq='D')
#
# Timezone-aware DatetimeIndex:
# DatetimeIndex(['2023-01-01 00:00:00-08:00', '2023-01-02 00:00:00-08:00',
#                '2023-01-03 00:00:00-08:00', '2023-01-04 00:00:00-08:00',
#                '2023-01-05 00:00:00-08:00'],
#               dtype='datetime64[ns, US/Pacific]', freq='D')
#
# Converted to US/Eastern:
# DatetimeIndex(['2022-12-31 19:00:00-05:00', '2023-01-01 19:00:00-05:00',
#                '2023-01-02 19:00:00-05:00', '2023-01-03 19:00:00-05:00',
#                '2023-01-04 19:00:00-05:00'],
#               dtype='datetime64[ns, US/Eastern]', freq='D')
#
# Timezone-aware DatetimeIndex:
# DatetimeIndex(['2023-01-01 00:00:00-08:00', '2023-01-02 00:00:00-08:00',
#                '2023-01-03 00:00:00-08:00', '2023-01-04 00:00:00-08:00',
#                '2023-01-05 00:00:00-08:00'],
#               dtype='datetime64[ns, US/Pacific]', freq='D')

# %%
# 4. Resampling
# -------------------------------------------------
# Create a time series
dates = pd.date_range('2023-01-01', periods=100, freq='H')
ts = pd.Series(np.random.randn(100), index=dates)
print(f"Original Time Series:\n{ts}\n")

# Downsampling (reducing frequency)
daily_mean = ts.resample('D').mean()
daily_sum = ts.resample('D').sum()
daily_min = ts.resample('D').min()
daily_max = ts.resample('D').max()
print(f"Daily Mean:\n{daily_mean}\n")
print(f"Daily Sum:\n{daily_sum}\n")
print(f"Daily Min:\n{daily_min}\n")
print(f"Daily Max:\n{daily_max}\n")

# Upsampling (increasing frequency)
daily_ts = ts.resample('D').mean()
hourly_ffill = daily_ts.resample('H').ffill()
hourly_bfill = daily_ts.resample('H').bfill()
hourly_interp = daily_ts.resample('H').interpolate(method='linear')
print(f"Hourly Forward Fill:\n{hourly_ffill}\n")
print(f"Hourly Backward Fill:\n{hourly_bfill}\n")
print(f"Hourly Interpolation:\n{hourly_interp}\n")
# Out:
# Original Time Series:
# 2023-01-01 00:00:00   -2.372785
# 2023-01-01 01:00:00    0.968237
# 2023-01-01 02:00:00    1.646953
# 2023-01-01 03:00:00    0.281591
# 2023-01-01 04:00:00   -0.120453
#                          ...
# 2023-01-04 23:00:00    0.953424
# 2023-01-05 00:00:00    0.325302
# 2023-01-05 01:00:00   -1.024136
# 2023-01-05 02:00:00    1.578416
# 2023-01-05 03:00:00   -0.574012
# Freq: H, Length: 100, dtype: float64
#
# Daily Mean:
# 2023-01-01   -0.102912
# 2023-01-02   -0.025946
# 2023-01-03    0.006415
# 2023-01-04   -0.261971
# 2023-01-05    0.076393
# Freq: D, dtype: float64
#
# Daily Sum:
# 2023-01-01   -2.469880
# 2023-01-02   -0.622703
# 2023-01-03    0.153952
# 2023-01-04   -6.287298
# 2023-01-05    0.305571
# Freq: D, dtype: float64
#
# Daily Min:
# 2023-01-01   -2.429176
# 2023-01-02   -1.725611
# 2023-01-03   -3.080944
# 2023-01-04   -1.831673
# 2023-01-05   -1.024136
# Freq: D, dtype: float64
#
# Daily Max:
# 2023-01-01    1.986533
# 2023-01-02    1.723798
# 2023-01-03    2.349865
# 2023-01-04    2.842327
# 2023-01-05    1.578416
# Freq: D, dtype: float64
#
# Hourly Forward Fill:
# 2023-01-01 00:00:00   -0.102912
# 2023-01-01 01:00:00   -0.102912
# 2023-01-01 02:00:00   -0.102912
# 2023-01-01 03:00:00   -0.102912
# 2023-01-01 04:00:00   -0.102912
#                          ...
# 2023-01-04 20:00:00   -0.261971
# 2023-01-04 21:00:00   -0.261971
# 2023-01-04 22:00:00   -0.261971
# 2023-01-04 23:00:00   -0.261971
# 2023-01-05 00:00:00    0.076393
# Freq: H, Length: 97, dtype: float64
#
# Hourly Backward Fill:
# 2023-01-01 00:00:00   -0.102912
# 2023-01-01 01:00:00   -0.025946
# 2023-01-01 02:00:00   -0.025946
# 2023-01-01 03:00:00   -0.025946
# 2023-01-01 04:00:00   -0.025946
#                          ...
# 2023-01-04 20:00:00    0.076393
# 2023-01-04 21:00:00    0.076393
# 2023-01-04 22:00:00    0.076393
# 2023-01-04 23:00:00    0.076393
# 2023-01-05 00:00:00    0.076393
# Freq: H, Length: 97, dtype: float64
#
# Hourly Interpolation:
# 2023-01-01 00:00:00   -0.102912
# 2023-01-01 01:00:00   -0.099705
# 2023-01-01 02:00:00   -0.096498
# 2023-01-01 03:00:00   -0.093291
# 2023-01-01 04:00:00   -0.090084
#                          ...
# 2023-01-04 20:00:00    0.019999
# 2023-01-04 21:00:00    0.034097
# 2023-01-04 22:00:00    0.048196
# 2023-01-04 23:00:00    0.062294
# 2023-01-05 00:00:00    0.076393
# Freq: H, Length: 97, dtype: float64

# %%
# 5. Shifting and Lagging
# -------------------------------------------------
# Create a simple time series
dates = pd.date_range('2023-01-01', periods=5, freq='D')
ts = pd.Series(range(1, 6), index=dates)
print(f"Original Time Series:\n{ts}\n")

# Shift values forward (lagging)
ts_lag1 = ts.shift(1)
ts_lag2 = ts.shift(2)
print(f"Lagged by 1:\n{ts_lag1}\n")
print(f"Lagged by 2:\n{ts_lag2}\n")

# Shift values backward (leading)
ts_lead1 = ts.shift(-1)
print(f"Leading by 1:\n{ts_lead1}\n")

# Shift the index (not the values)
ts_day_forward = ts.tshift(freq='1D')
print(f"Index shifted forward by 1 day:\n{ts_day_forward}\n")

# Calculate percent change
pct_change = ts.pct_change()
print(f"Percent Change:\n{pct_change}\n")

# Calculate difference
diff = ts.diff()
print(f"Difference:\n{diff}\n")
# Out:
# Original Time Series:
# 2023-01-01    1
# 2023-01-02    2
# 2023-01-03    3
# 2023-01-04    4
# 2023-01-05    5
# Freq: D, dtype: int64
#
# Lagged by 1:
# 2023-01-01    NaN
# 2023-01-02    1.0
# 2023-01-03    2.0
# 2023-01-04    3.0
# 2023-01-05    4.0
# Freq: D, dtype: float64
#
# Lagged by 2:
# 2023-01-01    NaN
# 2023-01-02    NaN
# 2023-01-03    1.0
# 2023-01-04    2.0
# 2023-01-05    3.0
# Freq: D, dtype: float64
#
# Leading by 1:
# 2023-01-01    2.0
# 2023-01-02    3.0
# 2023-01-03    4.0
# 2023-01-04    5.0
# 2023-01-05    NaN
# Freq: D, dtype: float64
#
# Index shifted forward by 1 day:
# 2023-01-02    1
# 2023-01-03    2
# 2023-01-04    3
# 2023-01-05    4
# 2023-01-06    5
# Freq: D, dtype: int64
#
# Percent Change:
# 2023-01-01         NaN
# 2023-01-02    1.000000
# 2023-01-03    0.500000
# 2023-01-04    0.333333
# 2023-01-05    0.250000
# Freq: D, dtype: float64
#
# Difference:
# 2023-01-01    NaN
# 2023-01-02    1.0
# 2023-01-03    1.0
# 2023-01-04    1.0
# 2023-01-05    1.0
# Freq: D, dtype: float64
# C:\Users\Hi\AppData\Local\Temp\ipykernel_14460\1517095807.py:19: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   ts_day_forward = ts.tshift(freq='1D')

# %%
# 6. Rolling and Expanding Windows
# -------------------------------------------------
# Create a longer time series
dates = pd.date_range('2023-01-01', periods=10, freq='D')
ts = pd.Series(range(1, 11), index=dates)
print(f"Original Time Series:\n{ts}\n")

# Rolling windows
rolling_mean = ts.rolling(window=3).mean()
rolling_sum = ts.rolling(window=3).sum()
rolling_std = ts.rolling(window=3).std()
print(f"Rolling Mean:\n{rolling_mean}\n")
print(f"Rolling Sum:\n{rolling_sum}\n")
print(f"Rolling Std Dev:\n{rolling_std}\n")

# Rolling window with min_periods
rolling_flex = ts.rolling(window=3, min_periods=1).mean()
print(f"Rolling with min_periods=1:\n{rolling_flex}\n")

# Expanding windows
expanding_mean = ts.expanding().mean()
expanding_sum = ts.expanding().sum()
print(f"Expanding Mean:\n{expanding_mean}\n")
print(f"Expanding Sum:\n{expanding_sum}\n")

# Exponentially weighted windows
ewm_mean = ts.ewm(alpha=0.3).mean()
print(f"Exponentially Weighted Mean:\n{ewm_mean}\n")
# Out:
# Original Time Series:
# 2023-01-01     1
# 2023-01-02     2
# 2023-01-03     3
# 2023-01-04     4
# 2023-01-05     5
# 2023-01-06     6
# 2023-01-07     7
# 2023-01-08     8
# 2023-01-09     9
# 2023-01-10    10
# Freq: D, dtype: int64
#
# Rolling Mean:
# 2023-01-01    NaN
# 2023-01-02    NaN
# 2023-01-03    2.0
# 2023-01-04    3.0
# 2023-01-05    4.0
# 2023-01-06    5.0
# 2023-01-07    6.0
# 2023-01-08    7.0
# 2023-01-09    8.0
# 2023-01-10    9.0
# Freq: D, dtype: float64
#
# Rolling Sum:
# 2023-01-01     NaN
# 2023-01-02     NaN
# 2023-01-03     6.0
# 2023-01-04     9.0
# 2023-01-05    12.0
# 2023-01-06    15.0
# 2023-01-07    18.0
# 2023-01-08    21.0
# 2023-01-09    24.0
# 2023-01-10    27.0
# Freq: D, dtype: float64
#
# Rolling Std Dev:
# 2023-01-01    NaN
# 2023-01-02    NaN
# 2023-01-03    1.0
# 2023-01-04    1.0
# 2023-01-05    1.0
# 2023-01-06    1.0
# 2023-01-07    1.0
# 2023-01-08    1.0
# 2023-01-09    1.0
# 2023-01-10    1.0
# Freq: D, dtype: float64
#
# Rolling with min_periods=1:
# 2023-01-01    1.0
# 2023-01-02    1.5
# 2023-01-03    2.0
# 2023-01-04    3.0
# 2023-01-05    4.0
# 2023-01-06    5.0
# 2023-01-07    6.0
# 2023-01-08    7.0
# 2023-01-09    8.0
# 2023-01-10    9.0
# Freq: D, dtype: float64
#
# Expanding Mean:
# 2023-01-01    1.0
# 2023-01-02    1.5
# 2023-01-03    2.0
# 2023-01-04    2.5
# 2023-01-05    3.0
# 2023-01-06    3.5
# 2023-01-07    4.0
# 2023-01-08    4.5
# 2023-01-09    5.0
# 2023-01-10    5.5
# Freq: D, dtype: float64
#
# Expanding Sum:
# 2023-01-01     1.0
# 2023-01-02     3.0
# 2023-01-03     6.0
# 2023-01-04    10.0
# 2023-01-05    15.0
# 2023-01-06    21.0
# 2023-01-07    28.0
# 2023-01-08    36.0
# 2023-01-09    45.0
# 2023-01-10    55.0
# Freq: D, dtype: float64
#
# Exponentially Weighted Mean:
# 2023-01-01    1.000000
# 2023-01-02    1.588235
# 2023-01-03    2.232877
# 2023-01-04    2.930517
# 2023-01-05    3.676788
# 2023-01-06    4.466682
# 2023-01-07    5.294883
# 2023-01-08    6.156064
# 2023-01-09    7.045121
# 2023-01-10    7.957353
# Freq: D, dtype: float64

# %%
# 7. Time Series Visualization
# -------------------------------------------------
dates = pd.date_range('2023-01-01', periods=100, freq='D')
ts1 = pd.Series(np.cumsum(np.random.randn(100)), index=dates)
ts2 = pd.Series(np.cumsum(np.random.randn(100) + 0.5), index=dates)
print(f"Time Series 1:\n{ts1}\n")
print(f"Time Series 2:\n{ts2}\n")

df_ts = pd.DataFrame({'Series1': ts1, 'Series2': ts2})
print(f"DataFrame for Visualization:\n{df_ts}\n")

df_ts.plot(title='Time Series Plot', figsize=(10, 5))
# Out:
# Time Series 1:
# 2023-01-01    -0.022868
# 2023-01-02     0.494940
# 2023-01-03    -0.308701
# 2023-01-04    -0.003330
# 2023-01-05     0.553509
#                 ...
# 2023-04-06   -14.623166
# 2023-04-07   -14.637224
# 2023-04-08   -14.506448
# 2023-04-09   -15.142161
# 2023-04-10   -14.911351
# Freq: D, Length: 100, dtype: float64
#
# Time Series 2:
# 2023-01-01     1.745685
# 2023-01-02     1.636847
# 2023-01-03     2.083211
# 2023-01-04     3.266662
# 2023-01-05     4.377280
#                 ...
# 2023-04-06    43.531977
# 2023-04-07    44.269063
# 2023-04-08    44.444243
# 2023-04-09    44.292849
# 2023-04-10    44.837500
# Freq: D, Length: 100, dtype: float64
#
# DataFrame for Visualization:
#               Series1    Series2
# 2023-01-01  -0.022868   1.745685
# 2023-01-02   0.494940   1.636847
# 2023-01-03  -0.308701   2.083211
# 2023-01-04  -0.003330   3.266662
# 2023-01-05   0.553509   4.377280
# ...               ...        ...
# 2023-04-06 -14.623166  43.531977
# 2023-04-07 -14.637224  44.269063
# 2023-04-08 -14.506448  44.444243
# 2023-04-09 -15.142161  44.292849
# 2023-04-10 -14.911351  44.837500
#
# [100 rows x 2 columns]
# <Axes: title={'center': 'Time Series Plot'}>

# %%
# 8. Periods and Frequency Conversion
# -------------------------------------------------
# Create a PeriodIndex
periods = pd.period_range(start='2023-01', periods=5, freq='M')
print(f"PeriodIndex:\n{periods}\n")

# Create a Series with PeriodIndex
period_series = pd.Series(range(1, 6), index=periods)
print(f"Series with PeriodIndex:\n{period_series}\n")

# Convert Period to Timestamp
periods_to_timestamp = periods.to_timestamp()
periods_to_timestamp_end = periods.to_timestamp(how='end')
print(f"Periods to Timestamp (start):\n{periods_to_timestamp}\n")
print(f"Periods to Timestamp (end):\n{periods_to_timestamp_end}\n")

# Convert Timestamp to Period
dates = pd.date_range('2023-01-01', periods=5, freq='D')
dates_to_daily_periods = dates.to_period('D')
dates_to_monthly_periods = dates.to_period('M')
print(f"Dates to Daily Periods:\n{dates_to_daily_periods}\n")
print(f"Dates to Monthly Periods:\n{dates_to_monthly_periods}\n")

# Frequency conversion
monthly_periods = pd.period_range(start='2023-01', periods=3, freq='M')
to_quarterly = monthly_periods.asfreq('Q')
to_weekly_start = monthly_periods.asfreq('W', how='start')
to_weekly_end = monthly_periods.asfreq('W', how='end')
print(f"Monthly Periods:\n{monthly_periods}\n")
print(f"To Quarterly:\n{to_quarterly}\n")
print(f"To Weekly (start):\n{to_weekly_start}\n")
print(f"To Weekly (end):\n{to_weekly_end}\n")
# Out:
# PeriodIndex:
# PeriodIndex(['2023-01', '2023-02', '2023-03', '2023-04', '2023-05'], dtype='period[M]')
#
# Series with PeriodIndex:
# 2023-01    1
# 2023-02    2
# 2023-03    3
# 2023-04    4
# 2023-05    5
# Freq: M, dtype: int64
#
# Periods to Timestamp (start):
# DatetimeIndex(['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01'], dtype='datetime64[ns]', freq='MS')
#
# Periods to Timestamp (end):
# DatetimeIndex(['2023-01-31 23:59:59.999999999', '2023-02-28 23:59:59.999999999',
#                '2023-03-31 23:59:59.999999999', '2023-04-30 23:59:59.999999999',
#                '2023-05-31 23:59:59.999999999'],
#               dtype='datetime64[ns]', freq=None)
#
# Dates to Daily Periods:
# PeriodIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'], dtype='period[D]')
#
# Dates to Monthly Periods:
# PeriodIndex(['2023-01', '2023-01', '2023-01', '2023-01', '2023-01'], dtype='period[M]')
#
# Monthly Periods:
# PeriodIndex(['2023-01', '2023-02', '2023-03'], dtype='period[M]')
#
# To Quarterly:
# PeriodIndex(['2023Q1', '2023Q1', '2023Q1'], dtype='period[Q-DEC]')
#
# To Weekly (start):
# PeriodIndex(['2022-12-26/2023-01-01', '2023-01-30/2023-02-05', '2023-02-27/2023-03-05'], dtype='period[W-SUN]')
#
# To Weekly (end):
# PeriodIndex(['2023-01-30/2023-02-05', '2023-02-27/2023-03-05', '2023-03-27/2023-04-02'], dtype='period[W-SUN]')

# %%
# 9. Time Deltas
# -------------------------------------------------
# Create a TimedeltaIndex
deltas = pd.timedelta_range(start='1 day', periods=5, freq='D')
print(f"TimedeltaIndex:\n{deltas}\n")

# Create a Series with TimedeltaIndex
delta_series = pd.Series(range(1, 6), index=deltas)
print(f"Series with TimedeltaIndex:\n{delta_series}\n")

# Arithmetic with dates
start_date = pd.Timestamp('2023-01-01')
date_plus_5days = start_date + pd.Timedelta(days=5)
date_plus_deltas = [start_date + delta for delta in deltas]
print(f"Start Date + 5 Days:\n{date_plus_5days}\n")
print(f"Start Date + Deltas:\n{date_plus_deltas}\n")

# TimedeltaIndex components
days = deltas.days
seconds = deltas.seconds
microseconds = deltas.microseconds
total_seconds = deltas.total_seconds()
print(f"Days: {days}\nSeconds: {seconds}\nMicroseconds: {microseconds}\nTotal Seconds: {total_seconds}\n")
# Out:
# TimedeltaIndex:
# TimedeltaIndex(['1 days', '2 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq='D')
#
# Series with TimedeltaIndex:
# 1 days    1
# 2 days    2
# 3 days    3
# 4 days    4
# 5 days    5
# Freq: D, dtype: int64
#
# Start Date + 5 Days:
# 2023-01-06 00:00:00
#
# Start Date + Deltas:
# [Timestamp('2023-01-02 00:00:00'), Timestamp('2023-01-03 00:00:00'), Timestamp('2023-01-04 00:00:00'), Timestamp('2023-01-05 00:00:00'), Timestamp('2023-01-06 00:00:00')]
#
# Days: Int64Index([1, 2, 3, 4, 5], dtype='int64')
# Seconds: Int64Index([0, 0, 0, 0, 0], dtype='int64')
# Microseconds: Int64Index([0, 0, 0, 0, 0], dtype='int64')
# Total Seconds: Float64Index([86400.0, 172800.0, 259200.00000000003, 345600.0, 432000.0], dtype='float64')
